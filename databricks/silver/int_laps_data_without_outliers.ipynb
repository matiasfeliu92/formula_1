// %%
%sql
SELECT
  *,
  is_pit_out_lap AS IS_PIT_OUT
FROM
  formula_1.int_transform_laps_data LIMIT 10;

WITH cleaned_laps AS (
  SELECT
    is_pit_out_lap AS IS_PIT_OUT
  FROM
    formula_1.int_transform_laps_data
)

// %%
%sql
WITH cleaned_laps AS (
  SELECT
    is_pit_out_lap AS IS_PIT_OUT,
    LEAD(is_pit_out_lap, 1, FALSE) OVER (PARTITION BY session_name, full_name ORDER BY lap_number) AS IS_PIT_IN
  FROM
    formula_1.int_transform_laps_data
)
SELECT
  *
FROM
  cleaned_laps
